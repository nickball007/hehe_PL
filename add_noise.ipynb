# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
test_photo = plt.imread('x.png')

# %%
plt.imshow(test_photo)

# %%
test_photo.shape
# Out:
# (1234, 608, 4)

# %%
test_photo[500][0]
# Out:
# array([0.2, 0.2, 0.2, 1. ], dtype=float32)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('image.png', cv2.IMREAD_UNCHANGED)
img_gray = 255 - test_photo[:, :, 3]

plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
img_gray
# Out:
# array([[254., 254., 254., ..., 254., 254., 254.],
#        [254., 254., 254., ..., 254., 254., 254.],
#        [254., 254., 254., ..., 254., 254., 254.],
#        ...,
#        [254., 254., 254., ..., 254., 254., 254.],
#        [254., 254., 254., ..., 254., 254., 254.],
#        [254., 254., 254., ..., 254., 254., 254.]], dtype=float32)

# %%
test_photo.shape
# Out:
# (708, 1260, 3)

# %% [markdown]
# draw circle by opencv

# %%
import numpy as np
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from random import randint

# %%
class draw_circle_by_opencv:
    def draw_circle_on_image(height, width, min_noise, max_noise, min_radius, max_radius):
        image = np.zeros(x.shape)
        image[:,:] = randint(165,255)
    
        for _ in range(min_noise, max_noise):
            radius = randint(min_radius, max_radius)
            x = randint(0, width)
            y = randint(0, height)
            cv2.circle(image,(x, y), radius, (0,0,0), -1) # -1 means fill up
        
        return(image)

# %%
image_2 = mpimg.imread(".//PL/2019/05/14/19513EAP/40_A1MAHP0226" + '.jpg')
x = image_2[0:image_2.shape[0]//2, 0:image_2.shape[1]//8]

image = np.zeros(x.shape)
image[:,:] = randint(165,255)
height = image.shape[0]
width = image.shape[1]
for _ in range(30, 150):
    radius = randint(1, 10)
    
    x = randint(0, width)
    y = randint(0, height)
    
    cv2.circle(image,(x, y), radius, (0,0,0), -1)

plt.imshow(image, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# draw circle by opencv: label transform

# %%
image[image[:,:] == 0] = 1

# %%
image[image[:,:] != 1] = 0

# %%
plt.imshow(image, cmap='gray', vmin=0, vmax=255)

# %%
plt.imsave("noise.png", image, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# add round noise

# %%
test_photo = np.zeros([708, 1260, 3])

# %%
test_photo.shape
# Out:
# (708, 1260, 3)

# %%
test_photo[:, :, :] = [255,255,255]

# %%
plt.imshow(test_photo)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
noise_number =  random.sample(range(1,100), random.randint(1,10))

# %%
noise_number
# Out:
# [83, 52, 36]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Circle

# Get an example image
import matplotlib.cbook as cbook
#image_file = cbook.get_sample_data('test_photo.jpg')
img =  np.zeros([708, 1260, 3])
img[:, :, :] = [255,255,255]

# Make some example data
x = np.random.rand(5)*img.shape[1]
y = np.random.rand(5)*img.shape[0]

# Create a figure. Equal aspect so circles look circular
fig,ax = plt.subplots(1)
ax.set_aspect('equal')

# Show the image
ax.imshow(img)

# Now, loop through coord arrays, and create a circle at each x,y pair
for xx,yy in zip(x,y):
    circ = Circle((xx,yy),random.randint(5, 20), color='k')
    ax.add_patch(circ)

# Show the image
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ax

# %%
imgs =  np.zeros([708, 1260, 3])
imgs[:, :, :] = [255,255,255]

# %%
difference = cv2.subtract(imgs, img)
b, g, r = cv2.split(difference)
if cv2.countNonZero(b) == 0 and cv2.countNonZero(g) == 0 and cv2.countNonZero(r) == 0:
    print("The images are completely Equal")
# Out:
# The images are completely Equal
