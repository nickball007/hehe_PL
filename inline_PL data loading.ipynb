# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.transform import rescale, resize, downscale_local_mean
from multiprocessing import Pool

# %%
import os

path = './/'

jpg_files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.jpg' in file:
            jpg_files.append(os.path.join(r, file).split("/")[7].split('.')[0])

len(jpg_files)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-7f709e4d04f2> in <module>
#       8     for file in f:
#       9         if '.jpg' in file:
# ---> 10             jpg_files.append(os.path.join(r, file).split("/")[7].split('.')[0])
#      11
#      12 len(jpg_files)
#
# IndexError: list index out of range

# %%
import os

path = './/'

jpg_files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.jpg' in file:
            jpg_files.append(os.path.join(r, file))

len(jpg_files)
# Out:
# 19344

# %%
jpg_files
# Out:
# ['.//test_photo.jpg',
#  './/PL/2019/05/14/19513EAP/22_A1MAHP0217.jpg',
#  './/PL/2019/05/14/19513EAP/42_A1MAHP0227.jpg',
#  './/PL/2019/05/14/19513EAP/4_A1MAHP0432.jpg',
#  './/PL/2019/05/14/19513EAP/62_A1MAHP0231.jpg',
#  './/PL/2019/05/14/19513EAP/74_A1MAHP0424.jpg',
#  './/PL/2019/05/14/19513EAP/12_A1MAHP0436.jpg',
#  './/PL/2019/05/14/19513EAP/10_A1MAHP0435.jpg',
#  './/PL/2019/05/14/19513EAP/36_A1MAHP0224.jpg',
#  './/PL/2019/05/14/19513EAP/64_A1MAHP0419.jpg',
#  './/PL/2019/05/14/19513EAP/44_A1MAHP0222.jpg',
#  './/PL/2019/05/14/19513EAP/68_A1MAHP0234.jpg',
#  './/PL/2019/05/14/19513EAP/14_A1MAHP0431.jpg',
#  './/PL/2019/05/14/19513EAP/16_A1MAHP0214.jpg',
#  './/PL/2019/05/14/19513EAP/70_A1MAHP0428.jpg',
#  './/PL/2019/05/14/19513EAP/84_A1MAHP0430.jpg',
#  './/PL/2019/05/14/19513EAP/30_A1MAHP0230.jpg',
#  './/PL/2019/05/14/19513EAP/46_A1MAHP0420.jpg',
#  './/PL/2019/05/14/19513EAP/28_A1MAHP0220.jpg',
#  './/PL/2019/05/14/19513EAP/48_A1MAHP0229.jpg',
# ...

# %%
csv_2 = pd.read_csv(".//Spectrum/2019/05/14/19513EAP/40_A1MAHP0226.csv")
csv_2
# Out:
#              0_0                     1_0         .1          2_0         .2  \
# 0     wavelength  intensity   wavelength  intensity   wavelength  intensity
# 1     898.232056  -5.807841   893.612671  -7.678084   893.478271   4.864731
# 2     904.986511   3.269642   900.772278   4.153796   901.028015   8.762409
# 3     911.738037   1.044972   907.874512  -7.864319   908.472046   2.085299
# 4     918.487305  -1.427444   914.924011  -2.139741   915.819031  -1.111042
# 5     925.234863   0.241462   921.925171   1.444464   923.077271   2.196147
# 6     931.981262  -0.100032   928.882019  -0.721892   930.254639   0.868148
# 7     938.726990  -0.338563   935.798645  -1.467561   937.358582  -1.178749
# 8     945.472351  -0.213266   942.678711  -0.727583   944.396118   1.181269
# 9     952.217834   0.248552   949.525818  -0.724150   951.373962   1.005890
# 10    958.963684   0.308779   956.343323  -1.487283   958.298401  -1.458678
# ...

# %%
image_2 = mpimg.imread(".//PL/2019/05/14/19513EAP/40_A1MAHP0226" + '.jpg')
plt.imshow(image_2, cmap='gray')
print(image_2.shape)
# Out:
# (2469, 4870)

# %%
csv_1 = pd.read_csv(".//Spectrum/2019/05/14/19513EAP/44_A1MAHP0222.csv")

# %%
csv_1
# Out:
#              0_0                     1_0         .1          2_0         .2  \
# 0     wavelength  intensity   wavelength  intensity   wavelength  intensity
# 1     898.232056  -5.216961   893.612671  -6.991106   893.478271   4.102450
# 2     904.986511   3.707808   900.772278   3.934349   901.028015   7.393765
# 3     911.738037   1.029989   907.874512  -7.409573   908.472046   1.749640
# 4     918.487305  -1.321896   914.924011  -1.419709   915.819031  -1.417297
# 5     925.234863  -0.035421   921.925171   2.027065   923.077271   2.671004
# 6     931.981262  -0.163839   928.882019  -0.476341   930.254639  -0.280636
# 7     938.726990  -0.051026   935.798645  -1.826069   937.358582  -1.108105
# 8     945.472351  -0.103668   942.678711  -0.564008   944.396118   1.364524
# 9     952.217834   0.267480   949.525818  -1.054227   951.373962   0.842724
# 10    958.963684   0.200156   956.343323  -1.739907   958.298401  -1.723982
# ...

# %%
image_1 = mpimg.imread(".//PL/2019/05/14/19513EAP/44_A1MAHP0222" + '.jpg')
plt.imshow(image_1,  cmap='gray')
print(image_1.shape)
# Out:
# (2469, 4870)

# %%
image_1[0][0]
# Out:
# 45

# %%
csv_files
# Out:
# ['.//Spectrum2/2019/05/23/00000523/20_17_24Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/4_17_16Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/22_17_28Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/18_A1UCHD0113.csv',
#  './/Spectrum2/2019/05/23/19523IAP/4_A1MAWP0335.csv',
#  './/Spectrum2/2019/08/2019-08-30.csv',
#  './/Spectrum2/2019/08/2019-08-21.csv',
#  './/Spectrum2/2019/08/2019-08-27.csv',
#  './/Spectrum2/2019/08/2019-08-20.csv',
#  './/Spectrum2/2019/08/2019-08-26.csv',
#  './/Spectrum2/2019/08/2019-08-24.csv',
#  './/Spectrum2/2019/08/2019-08-28.csv',
#  './/Spectrum2/2019/08/2019-08-29.csv',
#  './/Spectrum2/2019/08/2019-08-25.csv',
#  './/Spectrum2/2019/08/2019-08-23.csv',
#  './/Spectrum2/2019/08/2019-08-22.csv',
#  './/Spectrum2/2019/08/2019-08-31.csv',
#  './/Spectrum2/2019/08/31/19830EAE/50_A1M3VM0233.csv',
#  './/Spectrum2/2019/08/31/19830EAE/40_A1M3VM0134.csv',
#  './/Spectrum2/2019/08/31/19830EAE/18_A1M3VM0123.csv',
# ...

# %%
import os

path = './/'

csv_files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.csv' in file:
            csv_files.append(os.path.join(r, file))

len(csv_files)
# Out:
# 27764

# %%
num = []
for i in csv_files:
    num.append(len(i.split("/")))

# %%
csv_files
# Out:
# ['.//Spectrum2/2019/05/23/00000523/20_17_24Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/4_17_16Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/22_17_28Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/18_A1UCHD0113.csv',
#  './/Spectrum2/2019/05/23/19523IAP/4_A1MAWP0335.csv',
#  './/Spectrum2/2019/08/2019-08-30.csv',
#  './/Spectrum2/2019/08/2019-08-21.csv',
#  './/Spectrum2/2019/08/2019-08-27.csv',
#  './/Spectrum2/2019/08/2019-08-20.csv',
#  './/Spectrum2/2019/08/2019-08-26.csv',
#  './/Spectrum2/2019/08/2019-08-24.csv',
#  './/Spectrum2/2019/08/2019-08-28.csv',
#  './/Spectrum2/2019/08/2019-08-29.csv',
#  './/Spectrum2/2019/08/2019-08-25.csv',
#  './/Spectrum2/2019/08/2019-08-23.csv',
#  './/Spectrum2/2019/08/2019-08-22.csv',
#  './/Spectrum2/2019/08/2019-08-31.csv',
#  './/Spectrum2/2019/08/31/19830EAE/50_A1M3VM0233.csv',
#  './/Spectrum2/2019/08/31/19830EAE/40_A1M3VM0134.csv',
#  './/Spectrum2/2019/08/31/19830EAE/18_A1M3VM0123.csv',
# ...

# %%
import pandas as pd
from multiprocessing import Pool

# %%
csv_data = []
empty_file = []
def f(x):
    try:
        pd.read_csv(x, encoding="Big5", delim_whitespace=True)
    except:
        empty_file.append(x)

p = Pool(18)
p.map(f, csv_files)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
empty_file
# Out:
# []

# %%
csv_data = []
empty_file = []
for i in csv_files:
    try:
        csv_data.append(pd.read_csv(i, encoding="Big5", delim_whitespace=True))
    except:
        empty_file.append(i)

# %%
len(csv_data)

# %%
empty_file
# Out:
# ['.//Spectrum2/2019/05/23/00000523/20_17_24Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/4_17_16Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/22_17_28Empty.csv',
#  './/Spectrum2/2019/05/23/00000523/18_A1UCHD0113.csv',
#  './/Spectrum2/2019/05/23/19523IAP/4_A1MAWP0335.csv',
#  './/Spectrum2/2019/08/2019-08-30.csv',
#  './/Spectrum2/2019/08/2019-08-21.csv',
#  './/Spectrum2/2019/08/2019-08-27.csv',
#  './/Spectrum2/2019/08/2019-08-20.csv',
#  './/Spectrum2/2019/08/2019-08-26.csv',
#  './/Spectrum2/2019/08/2019-08-24.csv',
#  './/Spectrum2/2019/08/2019-08-28.csv',
#  './/Spectrum2/2019/08/2019-08-29.csv',
#  './/Spectrum2/2019/08/2019-08-25.csv',
#  './/Spectrum2/2019/08/2019-08-23.csv',
#  './/Spectrum2/2019/08/2019-08-22.csv',
#  './/Spectrum2/2019/08/2019-08-31.csv',
#  './/Spectrum2/2019/08/31/19830EAE/50_A1M3VM0233.csv',
#  './/Spectrum2/2019/08/31/19830EAE/40_A1M3VM0134.csv',
#  './/Spectrum2/2019/08/31/19830EAE/18_A1M3VM0123.csv',
# ...
